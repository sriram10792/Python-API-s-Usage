# %%
import  io
from google.cloud import vision
from google.cloud.vision import types
import argparse
import os
import python_utils

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="H:\\ANB\\Google vision\\file.json"

# %%
import  io
from google.cloud import vision
from google.cloud.vision import types
xxx=[]
def detect_text(file):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(file, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

file_name = "H:\\ANB\EEPM_Images\\EEPM- CHP\\trial.jpg"
detect_text(file_name)
# Out:
# Texts:
#
# "AIR CONDITIONER
# MODEL NO
# MODEL NO
# SERIAL NO
# MAX FUSE OR CKT. BKR. (HACR TYPE IN USA) 50
# RATED VOLTAGE 208/230 PH 1
# CA9048VKC1
# STYLE NO. 48GCA-0000942R
# MFR. NO. NCA9048VKC1
# し9624 32092
# AMPS
# HZ 60
# VOLTAGE: MIN. 197
# MAX. 253
# MINIMUM CIRCUIT AMPACITY:
# 31.0
# HP
# PH FLA RLA LRA
# COMPRESSOR:
# 23.7
# 129.0
# FAN:
# 1/4
# 1.4
# 3.3
# OUTDOOR UNIT SHIPPING CHARGE R22: 115 oz.
# TOTAL OPERATING CHARGE:
# TO ETERMINE TOTAL OPERATING CHARGE REFER TO TECH SHEET OR INSTALLATION INSTRUCTION
# DESIGN PRESSURE (PSIG): HIGH 300 LOW 150 FOR OUTDOOR USE
# TIFIED TO AR
# AIR-C
# RENDEMENT
# VERIFIED IGA
# FOR ENERGY . | ENERGETIQUE
# PERFORMANCE U VERFE
# EQUIPMEN
# STANDA
# "
# bounds: (523,654),(4735,654),(4735,3863),(523,3863)
#
# "AIR"
# bounds: (1365,654),(1794,667),(1790,804),(1361,791)
#
# "CONDITIONER"
# bounds: (1911,661),(3473,707),(3469,844),(1907,798)
#
# "MODEL"
# bounds: (563,893),(1048,893),(1048,976),(563,976)
#
# "NO"
# bounds: (1104,893),(1282,893),(1282,970),(1104,970)
#
# "MODEL"
# bounds: (555,1054),(1036,1046),(1037,1125),(556,1133)
#
# "NO"
# bounds: (1091,1046),(1268,1043),(1269,1119),(1092,1122)
#
# "SERIAL"
# bounds: (558,1217),(1042,1208),(1043,1284),(559,1293)
#
# "NO"
# bounds: (1101,1204),(1278,1201),(1279,1277),(1102,1280)
#
# "MAX"
# bounds: (523,1345),(816,1340),(818,1462),(525,1467)
#
# "FUSE"
# bounds: (877,1338),(1230,1332),(1232,1454),(879,1460)
#
# "OR"
# bounds: (1270,1333),(1457,1330),(1459,1452),(1272,1455)
#
# "CKT."
# bounds: (1519,1328),(1807,1323),(1809,1445),(1521,1450)
#
# "BKR."
# bounds: (1851,1323),(2156,1318),(2158,1440),(1853,1445)
#
# "(HACR"
# bounds: (2201,1318),(2592,1312),(2594,1434),(2203,1440)
#
# "TYPE"
# bounds: (2653,1310),(2921,1306),(2923,1428),(2655,1432)
#
# "IN"
# bounds: (2983,1305),(3087,1303),(3089,1425),(2985,1427)
#
# "USA)"
# bounds: (3149,1303),(3394,1299),(3396,1421),(3151,1425)
#
# "50"
# bounds: (3461,1295),(3620,1292),(3622,1414),(3463,1417)
#
# "RATED"
# bounds: (550,1514),(996,1503),(998,1584),(552,1596)
#
# "VOLTAGE"
# bounds: (1054,1496),(1656,1481),(1658,1562),(1056,1578)
#
# "208/230"
# bounds: (1788,1484),(2269,1472),(2271,1548),(1790,1560)
#
# "PH"
# bounds: (2414,1469),(2568,1465),(2570,1541),(2416,1545)
#
# "1"
# bounds: (2666,1466),(2712,1465),(2714,1536),(2668,1537)
#
# "CA9048VKC1"
# bounds: (1675,880),(2423,887),(2422,958),(1674,951)
#
# "STYLE"
# bounds: (2948,1031),(3284,1046),(3280,1122),(2945,1107)
#
# "NO."
# bounds: (3330,1046),(3507,1054),(3504,1123),(3327,1115)
#
# "48GCA-0000942R"
# bounds: (3582,1061),(4440,1098),(4437,1169),(3579,1132)
#
# "MFR."
# bounds: (2938,1184),(3218,1190),(3217,1261),(2937,1255)
#
# "NO."
# bounds: (3272,1189),(3449,1193),(3448,1262),(3271,1258)
#
# "NCA9048VKC1"
# bounds: (3589,1197),(4234,1210),(4233,1276),(3588,1263)
#
# "し"
# bounds: (1662,1202),(1731,1202),(1731,1278),(1662,1278)
#
# "9624"
# bounds: (1733,1199),(2028,1200),(2028,1279),(1733,1278)
#
# "32092"
# bounds: (2057,1202),(2415,1203),(2415,1279),(2057,1278)
#
# "AMPS"
# bounds: (4080,1313),(4330,1312),(4330,1378),(4080,1379)
#
# "HZ"
# bounds: (3418,1461),(3549,1449),(3556,1528),(3425,1540)
#
# "60"
# bounds: (3645,1443),(3754,1434),(3760,1504),(3651,1514)
#
# "VOLTAGE:"
# bounds: (530,1670),(1209,1640),(1213,1724),(534,1754)
#
# "MIN."
# bounds: (1272,1642),(1570,1629),(1573,1711),(1276,1724)
#
# "197"
# bounds: (1705,1620),(1917,1611),(1920,1687),(1708,1696)
#
# "MAX."
# bounds: (2975,1594),(3255,1593),(3255,1664),(2975,1665)
#
# "253"
# bounds: (3383,1597),(3563,1596),(3563,1667),(3383,1668)
#
# "MINIMUM"
# bounds: (571,1806),(1225,1777),(1229,1859),(575,1888)
#
# "CIRCUIT"
# bounds: (1287,1776),(1811,1753),(1814,1832),(1290,1855)
#
# "AMPACITY:"
# bounds: (1864,1755),(2543,1725),(2547,1801),(1867,1831)
#
# "31.0"
# bounds: (2978,1745),(3215,1738),(3217,1809),(2980,1816)
#
# "HP"
# bounds: (1909,1884),(2085,1884),(2085,1967),(1909,1967)
#
# "PH"
# bounds: (2482,1866),(2641,1861),(2643,1935),(2484,1940)
#
# "FLA"
# bounds: (2948,1859),(3150,1853),(3152,1924),(2950,1930)
#
# "RLA"
# bounds: (3423,1843),(3628,1837),(3630,1906),(3425,1912)
#
# "LRA"
# bounds: (3924,1821),(4106,1815),(4108,1884),(3926,1890)
#
# "COMPRESSOR:"
# bounds: (558,2148),(1539,2105),(1543,2192),(562,2235)
#
# "23.7"
# bounds: (3426,2015),(3647,2000),(3652,2070),(3431,2086)
#
# "129.0"
# bounds: (3931,1982),(4178,1965),(4183,2034),(3936,2051)
#
# "FAN:"
# bounds: (1245,2331),(1543,2318),(1546,2400),(1249,2413)
#
# "1/4"
# bounds: (1926,2301),(2110,2269),(2126,2356),(1941,2389)
#
# "1.4"
# bounds: (2968,2231),(3101,2219),(3109,2308),(2976,2320)
#
# "3.3"
# bounds: (3929,2176),(4070,2164),(4076,2232),(3935,2245)
#
# "OUTDOOR"
# bounds: (593,2555),(1259,2508),(1265,2592),(599,2639)
#
# "UNIT"
# bounds: (1323,2510),(1632,2488),(1638,2567),(1329,2589)
#
# "SHIPPING"
# bounds: (1682,2485),(2302,2441),(2308,2517),(1687,2561)
#
# "CHARGE"
# bounds: (2359,2437),(2850,2402),(2855,2478),(2364,2513)
#
# "R22:"
# bounds: (2903,2399),(3145,2382),(3151,2458),(2908,2475)
#
# "115"
# bounds: (3456,2347),(3631,2335),(3636,2405),(3461,2418)
#
# "oz."
# bounds: (3941,2339),(4090,2328),(4095,2399),(3946,2410)
#
# "TOTAL"
# bounds: (578,2709),(1001,2677),(1010,2796),(587,2828)
#
# "OPERATING"
# bounds: (1081,2671),(1832,2615),(1841,2733),(1090,2790)
#
# "CHARGE:"
# bounds: (1899,2611),(2464,2569),(2473,2687),(1908,2730)
#
# "TO"
# bounds: (596,2900),(715,2890),(721,2958),(602,2969)
#
# "ETERMINE"
# bounds: (827,2882),(1276,2843),(1282,2911),(833,2951)
#
# "TOTAL"
# bounds: (1315,2845),(1592,2821),(1598,2887),(1321,2911)
#
# "OPERATING"
# bounds: (1625,2822),(2104,2780),(2109,2841),(1630,2883)
#
# "CHARGE"
# bounds: (2140,2777),(2467,2748),(2472,2809),(2145,2838)
#
# "REFER"
# bounds: (2503,2747),(2755,2725),(2760,2784),(2508,2806)
#
# "TO"
# bounds: (2784,2721),(2883,2712),(2888,2768),(2789,2777)
#
# "TECH"
# bounds: (2913,2709),(3109,2692),(3114,2751),(2918,2768)
#
# "SHEET"
# bounds: (3142,2686),(3371,2666),(3376,2725),(3147,2745)
#
# "OR"
# bounds: (3398,2664),(3497,2655),(3502,2711),(3403,2720)
#
# "INSTALLATION"
# bounds: (3526,2648),(4000,2607),(4006,2667),(3531,2709)
#
# "INSTRUCTION"
# bounds: (4030,2598),(4442,2562),(4447,2618),(4035,2654)
#
# "DESIGN"
# bounds: (588,3071),(1113,3020),(1126,3158),(601,3209)
#
# "PRESSURE"
# bounds: (1184,3013),(1891,2944),(1904,3083),(1197,3151)
#
# "(PSIG):"
# bounds: (1937,2940),(2386,2896),(2399,3035),(1950,3078)
#
# "HIGH"
# bounds: (2409,2892),(2716,2862),(2729,3001),(2422,3030)
#
# "300"
# bounds: (2812,2855),(3138,2823),(3152,2962),(2825,2993)
#
# "LOW"
# bounds: (3212,2814),(3448,2791),(3461,2929),(3225,2952)
#
# "150"
# bounds: (3541,2784),(3730,2766),(3744,2904),(3554,2922)
#
# "FOR"
# bounds: (3803,2759),(4037,2736),(4050,2875),(3816,2897)
#
# "OUTDOOR"
# bounds: (4085,2734),(4532,2691),(4545,2829),(4098,2872)
#
# "USE"
# bounds: (4580,2684),(4721,2670),(4735,2809),(4593,2822)
#
# "TIFIED"
# bounds: (3874,2943),(4098,2923),(4105,3007),(3881,3027)
#
# "TO"
# bounds: (4100,2923),(4179,2916),(4184,2975),(4105,2982)
#
# "AR"
# bounds: (4180,2943),(4236,2938),(4240,2989),(4184,2994)
#
# "AIR-C"
# bounds: (4082,3094),(4196,3099),(4194,3138),(4080,3133)
#
# "RENDEMENT"
# bounds: (3086,3217),(3459,3167),(3471,3261),(3098,3310)
#
# "VERIFIED"
# bounds: (2364,3287),(2669,3274),(2673,3383),(2369,3396)
#
# "IGA"
# bounds: (2779,3267),(2996,3258),(3001,3379),(2784,3389)
#
# "FOR"
# bounds: (2301,3456),(2442,3438),(2455,3536),(2314,3554)
#
# "ENERGY"
# bounds: (2462,3438),(2730,3403),(2743,3501),(2475,3536)
#
# "."
# bounds: (2897,3428),(2946,3422),(2953,3477),(2904,3484)
#
# "|"
# bounds: (3003,3363),(3017,3361),(3031,3472),(3017,3474)
#
# "ENERGETIQUE"
# bounds: (3053,3360),(3483,3304),(3497,3407),(3066,3463)
#
# "PERFORMANCE"
# bounds: (2279,3604),(2776,3533),(2798,3688),(2301,3759)
#
# "U"
# bounds: (2802,3529),(2831,3525),(2853,3680),(2824,3684)
#
# "VERFE"
# bounds: (3094,3486),(3384,3444),(3406,3600),(3116,3641)
#
# "EQUIPMEN"
# bounds: (3969,3657),(4195,3637),(4200,3696),(3974,3716)
#
# "STANDA"
# bounds: (3906,3803),(4182,3803),(4182,3863),(3906,3863)

# %%
# Out:
# []

# %%
def parse_image(image_path=None):
    
    client = vision.ImageAnnotatorClient()
    response = client.text_detection(image=open(image_path, 'rb'))
    text = response.text_annotations
    del response     # to clean-up the system memory

    return text[0].description


image_content = parse_image(image_path="H:\\ANB\EEPM_Images\\EEPM- CHP\\trial.jpg")

my_formatted_text = ""
for line in image_content.split("\n"):
    my_formatted_text += "    " + line + "\n"

# %%
my_formatted_text
# Out:
# '    AIR CONDITIONER\n    MODEL NO\n    MODEL NO\n    SERIAL NO\n    MAX FUSE OR CKT. BKR. (HACR TYPE IN USA) 50\n    RATED VOLTAGE 208/230 PH 1\n    CA9048VKC1\n    STYLE NO. 48GCA-0000942R\n    MFR. NO. NCA9048VKC1\n    し9624 32092\n    AMPS\n    HZ 60\n    VOLTAGE: MIN. 197\n    MAX. 253\n    MINIMUM CIRCUIT AMPACITY:\n    31.0\n    HP\n    PH FLA RLA LRA\n    COMPRESSOR:\n    23.7\n    129.0\n    FAN:\n    1/4\n    1.4\n    3.3\n    OUTDOOR UNIT SHIPPING CHARGE R22: 115 oz.\n    TOTAL OPERATING CHARGE:\n    TO ETERMINE TOTAL OPERATING CHARGE REFER TO TECH SHEET OR INSTALLATION INSTRUCTION\n    DESIGN PRESSURE (PSIG): HIGH 300 LOW 150 FOR OUTDOOR USE\n    TIFIED TO AR\n    AIR-C\n    RENDEMENT\n    VERIFIED IGA\n    FOR ENERGY . | ENERGETIQUE\n    PERFORMANCE U VERFE\n    EQUIPMEN\n    STANDA\n    \n'

# %%
my_formatted_text
# Out:
# '    AIR CONDITIONER\n    MODEL NO\n    MODEL NO\n    SERIAL NO\n    MAX FUSE OR CKT. BKR. (HACR TYPE IN USA) 50\n    RATED VOLTAGE 208/230 PH 1\n    CA9048VKC1\n    STYLE NO. 48GCA-0000942R\n    MFR. NO. NCA9048VKC1\n    し9624 32092\n    AMPS\n    HZ 60\n    VOLTAGE: MIN. 197\n    MAX. 253\n    MINIMUM CIRCUIT AMPACITY:\n    31.0\n    HP\n    PH FLA RLA LRA\n    COMPRESSOR:\n    23.7\n    129.0\n    FAN:\n    1/4\n    1.4\n    3.3\n    OUTDOOR UNIT SHIPPING CHARGE R22: 115 oz.\n    TOTAL OPERATING CHARGE:\n    TO ETERMINE TOTAL OPERATING CHARGE REFER TO TECH SHEET OR INSTALLATION INSTRUCTION\n    DESIGN PRESSURE (PSIG): HIGH 300 LOW 150 FOR OUTDOOR USE\n    TIFIED TO AR\n    AIR-C\n    RENDEMENT\n    VERIFIED IGA\n    FOR ENERGY . | ENERGETIQUE\n    PERFORMANCE U VERFE\n    EQUIPMEN\n    STANDA\n    \n'
